# %% [markdown]
# # 11/12/2025

# %% [markdown]
# # Feature Engineering :

# %% [markdown]
# - So far we have performed feature analysis
#   - Data Frame quick checks
#   - Categorical column analysis
#   - Bar Charts , Pie Charts
#   - Numerical column analysis
#   - Histograms , box plots, outliers
#   - Bi - variat analysis
#   - Correlation etc

# %% [markdown]
# - Now we need to learn Feature Engineering
#   - We will create a new columns for better ML models
#   - We will perform the **Encoding** , which is convert categorical to Numerical data
#   - We will do **data transformations**
#   - We will perform **Scaling: Standardizations and Normalization**
#   - We will perform the **missing value analysis**
# -

# %% [markdown]
# - Feature Analysis
# - Feature Engineering
# - Feature Selection
# - Model Development
# - Model Evaluation
# - Model Tuning ( If model does not perform properly then model we do model tuning)
# - Model Deployment

# %% [markdown]
# # Encoding
#
# - Convert categorical data to Numerical data
# - ML/DL or any models works based on mathematics
# - Models cannot understand English Character
# - So it is very important to convert categorical values to numerical values
# - For example Gender column has 2 tables
#   - Male
#   - Female
# - Then Female represent as 0, Male represent as 1 based on alphabetical order

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Visa_df = pd.read_csv(r"C:\Users\heman\Data_Files\Visadataset.csv")
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat = Visa_df.select_dtypes(include="object").columns
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num = Visa_df.select_dtypes(exclude="object").columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
l = ['Apple','Banana']

# %%
# Step 1: Read the data
# Step 2: Get the categorical column
# For loop on cat start with 1
# lables = sorted(visa_df[i].unique())
  # d={i:j for i,j in enumerate(lables)}
  # visa_df[i] = visa_df[i].map(d)

# %%
cat = Visa_df.select_dtypes(include="object").columns
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
for i in

# %% [markdown]
# # Lable Encoder :
#
# - **LableEncoder** is a method will convert cat lables to numerical values
# - It is under package : **sklearn (sickit -learn)**
#    - The class Name : **preprocessing**
#        - The method name is : **LabelEncoder**

# %%
# from <package>.<class> import <method>

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# - Step -1 : import the method
# - Step -2 : save the method
# - Step -3 : Apply fit transform
#
# - **Fit transform**
#     - **fit** :means find the logic
#         - in above example fit means create mapper or dict
#     - **transform** : apply the logic and change the data
#         - apply the **mapper on data**

# %%
# Read the data again
Visa_df = pd.read_csv(r"C:\Users\heman\Data_Files\Visadataset.csv")
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat = Visa_df.select_dtypes(include="object").columns
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
# Import the method 
from sklearn.preprocessing import LabelEncoder

#  Save the Method
le = LabelEncoder()

# Apply fit transform
Visa_df['case_status'] = le.fit_transform(Visa_df['case_status'])
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# Read the data
# Get Cat columns
# Apply for loop on above logic

# %% [markdown]
# # One Hot Encoder
#
# - First how many labels are there in a columns
# - That many new columns will be created extra
# - For example case status has 2 lables
#      - Certified
#      - Denied
# - So it will create Two extra new columns
#    - case_study_Certified
#    - case_status_Denied
#
# - At a time one column value become 1 other value become 0
# - This means a **one hot encoder**

# %%
# continent C_A  C_Af   C_E
# Asia       1    0      0
# Africa     0    1      0
# Europe     0    0      1

# %% [markdown]
# ## pd.get_dummies

# %%
# Read the data again
Visa_df = pd.read_csv(r"C:\Users\heman\Data_Files\Visadataset.csv")
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat = Visa_df.select_dtypes(include="object").columns
cat

# %%
pd.get_dummies(Visa_df['case_status'])
# Out:
#        Certified  Denied
# 0          False    True
# 1           True   False
# 2          False    True
# 3          False    True
# 4           True   False
# ...          ...     ...
# 25475       True   False
# 25476       True   False
# 25477       True   False
# 25478       True   False
# 25479       True   False
#
# [25480 rows x 2 columns]

# %%
pd.get_dummies(Visa_df['case_status'],dtype=int)
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]

# %%
pd.get_dummies(Visa_df['continent'])
# Out:
#        Africa   Asia  Europe  North America  Oceania  South America
# 0       False   True   False          False    False          False
# 1       False   True   False          False    False          False
# 2       False   True   False          False    False          False
# 3       False   True   False          False    False          False
# 4        True  False   False          False    False          False
# ...       ...    ...     ...            ...      ...            ...
# 25475   False   True   False          False    False          False
# 25476   False   True   False          False    False          False
# 25477   False   True   False          False    False          False
# 25478   False   True   False          False    False          False
# 25479   False   True   False          False    False          False
#
# [25480 rows x 6 columns]

# %% [markdown]
# # 12/12/2025

# %% [markdown]
# # We have 2 types of scaling :
#
# - Z score(Standardization)
# - Min Max scalar(Normalisation)

# %% [markdown]
# ## Zscore

# %% [markdown]
# <img src="https://i.ytimg.com/vi/GVbr-nKQZs8/maxresdefault.jpg" id="img" style="width: 350px; height: 197px;">

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Visa_df = pd.read_csv(r"C:\Users\heman\Data_Files\Visadataset.csv")
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat = Visa_df.select_dtypes(include='object').columns
num = Visa_df.select_dtypes(exclude='object').columns
print(cat)
print(num)
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
# Step 1: Take the pwage data
# Step 2: Calculate the mean of data
# Step 3: Calculate the std of data
# Step 4: Nr = data-mean , step1 - step2
# Step 5: z_Wage = Nr/std = Step4/Step3
# Step 6: Create a new column Visa_df['z_Wage'] = z_Wage

# %%
wage_data = Visa_df['prevailing_wage']
wage_mean = wage_data.mean()
wage_std = wage_data.std()

Nr = wage_data - wage_mean
z_Wage = Nr/wage_std

Visa_df['z_Wage'] = z_Wage

# %%
Visa_df['z_Wage']
# Out:
# 0       -1.398510
# 1        0.169832
# 2        0.919060
# 3        0.169991
# 4        1.428576
#            ...
# 25475    0.049923
# 25476    3.876083
# 25477    1.360253
# 25478    0.221504
# 25479   -0.067762
# Name: z_Wage, Length: 25480, dtype: float64

# %%
Visa_df[['prevailing_wage','z_Wage']]
# Out:
#        prevailing_wage    z_Wage
# 0             592.2029 -1.398510
# 1           83425.6500  0.169832
# 2          122996.8600  0.919060
# 3           83434.0300  0.169991
# 4          149907.3900  1.428576
# ...                ...       ...
# 25475       77092.5700  0.049923
# 25476      279174.7900  3.876083
# 25477      146298.8500  1.360253
# 25478       86154.7700  0.221504
# 25479       70876.9100 -0.067762
#
# [25480 rows x 2 columns]

# %%
plt.figure(figsize=(12,6))
plt.suptitle('Raw_Data Vs Z-Data')
plt.subplot(2,2,1).hist(wage_data)
plt.title('Prevailing_wage')
plt.subplot(2,2,2).hist(z_Wage)
plt.subplot(2,2,3).boxplot(wage_data,vert=False)
plt.subplot(2,2,4).boxplot(z_Wage,vert=False)

plt.show()

# %% [markdown]
# # Standard Scalar
#
# - Sklearn
#     - preprocessing
#         - StandardScalar

# %%
# Step1 : import the method
# Step2 : Save the method
# Step3 : Apply the fit transform

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

ss.fit_transform(Visa_df['prevailing_wage'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 ss = StandardScaler()
# ----> 3 ss.fit_transform(Visa_df['prevailing_wage'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:878, in TransformerMixin.fit_transform(self, X, y, **fit_params)
# ...

# %%
wage_ss = ss.fit_transform(Visa_df[['prevailing_wage']])

Visa_df['wage_ss'] = wage_ss

# %%
Visa_df[['prevailing_wage','z_Wage','wage_ss']]
# Out:
#        prevailing_wage    z_Wage   wage_ss
# 0             592.2029 -1.398510 -1.398537
# 1           83425.6500  0.169832  0.169835
# 2          122996.8600  0.919060  0.919079
# 3           83434.0300  0.169991  0.169994
# 4          149907.3900  1.428576  1.428604
# ...                ...       ...       ...
# 25475       77092.5700  0.049923  0.049924
# 25476      279174.7900  3.876083  3.876159
# 25477      146298.8500  1.360253  1.360280
# 25478       86154.7700  0.221504  0.221509
# 25479       70876.9100 -0.067762 -0.067763
#
# [25480 rows x 3 columns]

# %% [markdown]
# # Derivation of Standard Scalar :

# %%
Visa_df['prevailing_wage'].values
# Out:
# array([   592.2029,  83425.65  , 122996.86  , ..., 146298.85  ,
#         86154.77  ,  70876.91  ])

# %%
Visa_df['prevailing_wage'].values.reshape(-1,1)
# Out:
# array([[   592.2029],
#        [ 83425.65  ],
#        [122996.86  ],
#        ...,
#        [146298.85  ],
#        [ 86154.77  ],
#        [ 70876.91  ]])

# %%
ss.fit_transform()

# %% [markdown]
# # MinMax Scalar :

# %% [markdown]
# <img src="https://aiml.com/wp-content/uploads/2023/04/min-max-normalizer.png" id="img" style="width: 350px; height: 116px;">

# %% [markdown]
# ## MinMax Scalar Derivation :

# %%
# Step 1 : Read the data
# Step 2 : Calculate min
# Step 3 : Calculate max
# Step 4 : Nr = Step1 - Step2
# Step 5 : Dr = Step3 - Step2
# Step 6 : Nr/Dr
# Step 7 : Visa_df['wage_min_max'] = Nr/Dr

# %%
Visa_df = pd.read_csv(r"C:\Users\heman\Data_Files\Visadataset.csv")
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
wage_data = Visa_df['prevailing_wage']

# %%
wage_data_min = wage_data.min
wage_data_min
# Out:
# 2.1367

# %%
wage_data_max = wage_data.max
wage_data_max
# Out:
# 319210.27

# %%
## Package method :

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler
mms.fit_transform(Visa_df['prevailing_wage'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 3
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 mms = MinMaxScaler
# ----> 3 mms.fit_transform(Visa_df['prevailing_wage'])
#
# TypeError: TransformerMixin.fit_transform() missing 1 required positional argument: 'X'
